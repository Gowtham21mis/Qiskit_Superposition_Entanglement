# %% [markdown]
# # Superposition and Entanglement in Qiskit
# This notebook demonstrates:
# 1. **Superposition** using a single qubit.
# 2. **Entanglement** using two qubits.
# We will use Qiskit to create circuits, visualize the states, and measure outcomes.

# %%
# ===========================
# Install Qiskit, Aer and pylatexenc
# ===========================
# !pip install qiskit --quiet
# !pip install qiskit-aer --quiet

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\K Madhumitha\AppData\Local\Programs\Python\Python313\python.exe

# %%
# ===========================
# Import Libraries
# ===========================
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Superposition Example

# %%
# ===========================
# Superposition Example
# ===========================
# Create 1-qubit circuit
qc_super = QuantumCircuit(1)

# Apply Hadamard gate to create superposition
qc_super.h(0)

# Draw the circuit
qc_super.draw('text')

# Get statevector
state_super = Statevector.from_instruction(qc_super)
plot_bloch_multivector(state_super)
plt.show()

# Measure and simulate
qc_super.measure_all()
simulator = AerSimulator()
job_super = simulator.run(qc_super, shots=1024)
result_super = job_super.result()
counts_super = result_super.get_counts()
print("Superposition Measurement Counts:", counts_super)
plot_histogram(counts_super)
plt.show()
# Out:
# Superposition Measurement Counts: {'1': 505, '0': 519}

# %% [markdown]
# ## 2. Entanglement Example

# %%
# ===========================
# Entanglement Example
# ===========================
# Create 2-qubit circuit
qc_ent = QuantumCircuit(2)

# Apply Hadamard on qubit 0
qc_ent.h(0)

# Apply CNOT to entangle qubit 0 and 1
qc_ent.cx(0, 1)

# Draw the circuit
qc_ent.draw('text')

# Get statevector
state_ent = Statevector.from_instruction(qc_ent)
print("Entangled Statevector:", state_ent)
plot_bloch_multivector(state_ent)
plt.show()

# Measure and simulate
qc_ent.measure_all()
job_ent = simulator.run(qc_ent, shots=1024)
result_ent = job_ent.result()
counts_ent = result_ent.get_counts()
print("Entanglement Measurement Counts:", counts_ent)
plot_histogram(counts_ent)
plt.show()
# Out:
# Entangled Statevector: Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
# Entanglement Measurement Counts: {'00': 508, '11': 516}

# %%
# %matplotlib inline

# %% [markdown]
# Task 1: Superposition

# %%
# Task 1: Superposition (Student Task)
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create a single qubit circuit
qc_task1 = QuantumCircuit(1, 1)
qc_task1.h(0)                # Apply Hadamard gate to get superposition
qc_task1.measure(0, 0)       # Measure the qubit

# Simulate
sim = AerSimulator()
job1 = sim.run(qc_task1, shots=1024)
result1 = job1.result()
counts1 = result1.get_counts()

print("Task 1 (Superposition) Measurement Counts:", counts1)
plot_histogram(counts1)
plt.show()
# Out:
# Task 1 (Superposition) Measurement Counts: {'0': 507, '1': 517}

# %% [markdown]
# Task 1: Superposition (Bloch Sphere)

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

qc1_viz = QuantumCircuit(1)
qc1_viz.h(0)
state1 = Statevector.from_instruction(qc1_viz)
plot_bloch_multivector(state1)
plt.show()

# %% [markdown]
# Task 2: Entanglement

# %%
# Task 2: Entanglement (Student Task)
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create a 2-qubit circuit
qc_task2 = QuantumCircuit(2, 2)
qc_task2.h(0)                # Hadamard on qubit 0
qc_task2.cx(0, 1)            # CNOT entangles qubits 0 and 1
qc_task2.measure([0, 1], [0, 1])   # Measure both qubits

# Simulate
sim = AerSimulator()
job2 = sim.run(qc_task2, shots=1024)
result2 = job2.result()
counts2 = result2.get_counts()

print("Task 2 (Entanglement) Measurement Counts:", counts2)
plot_histogram(counts2)
plt.show()
# Out:
# Task 2 (Entanglement) Measurement Counts: {'00': 498, '11': 526}

# %% [markdown]
# Task 2: Entanglement (Statevector and Histogram)

# %%
# Optional: Visualize the statevector for the entangled state (before measurement)
qc2_viz = QuantumCircuit(2)
qc2_viz.h(0)
qc2_viz.cx(0, 1)
state2 = Statevector.from_instruction(qc2_viz)
print("Statevector of Bell State:\n", state2)

from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(state2)
plt.show()
# Out:
# Statevector of Bell State:
#  Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
